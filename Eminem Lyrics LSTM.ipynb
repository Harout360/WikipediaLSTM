# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Default settings
#     Sequence length = 40
#     Step = 3
#     Units = 128
#     LSTM, DENSE, ACTIVATION
#     Learn Rate = 0.01
#     Batch size = 128
#     Epochs = 1

# %%
defaults = {'maxlen': 40, 'step': 3, 'units': 128, 'learnRate':0.01, 'batchSize':128, 'epochs':1}

#Units
test1 = defaults.copy()
test1['units'] = 256

#2nd LSTM Layer
test2 = defaults.copy()

#Step Size
test3 = defaults.copy()
test3['step'] = 2

#Learn rate
test4 = defaults.copy()
test4['learnRate'] = 0.001

#Batch size
test5 = defaults.copy()
test5['batchSize'] = 64

#Epochs
test6 = defaults.copy()
test6['epochs'] = 3

#Sequence length
test7 = defaults.copy()
test7['maxlen'] = 70

testBank =[defaults, test1, test2, test3, test4, test5, test6, test7]
for test in testBank:
    print(test)
# Out:
# {'step': 3, 'learnRate': 0.01, 'batchSize': 128, 'units': 128, 'epochs': 1, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.01, 'batchSize': 128, 'units': 256, 'epochs': 1, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.01, 'batchSize': 128, 'units': 128, 'epochs': 1, 'maxlen': 40}
# {'step': 2, 'learnRate': 0.01, 'batchSize': 128, 'units': 128, 'epochs': 1, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.001, 'batchSize': 128, 'units': 128, 'epochs': 1, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.01, 'batchSize': 64, 'units': 128, 'epochs': 1, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.01, 'batchSize': 128, 'units': 128, 'epochs': 3, 'maxlen': 40}
# {'step': 3, 'learnRate': 0.01, 'batchSize': 128, 'units': 128, 'epochs': 1, 'maxlen': 70}

# %% [markdown]
# ## Get Eminem Lyrics

# %%
filename = "Eminem/eminem-lyrics.txt"
text = open(filename, "r", encoding="utf8").read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 1423348
# total chars: 90

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Build Model, Train, Test, Repeat

# %%
for testNum, test in enumerate(testBank):
    print("Test Number", testNum)
    # cut the text in semi-redundant sequences of maxlen characters
    maxlen = test['maxlen']
    step = test['step']
    sentences = []
    next_chars = []
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
    print('nb sequences:', len(sentences))

    print('Vectorization...')
    X = None
    y = None
    X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            X[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1

    print('Vectorized.')

    # build the model: a single LSTM
    print('Build model...')
    model = Sequential()
    
    if testNum != 2:
        model.add(LSTM(test['units'], input_shape=(maxlen, len(chars))))
    else :
        print('Adding second LSTM layer with units : ' + str(test['units']))
        model.add(LSTM(test['units'], input_shape=(maxlen, len(chars)),return_sequences=True))
        model.add(LSTM(test['units']))
        
    model.add(Dense(len(chars)))
    model.add(Activation('softmax'))

    optimizer = RMSprop(lr=test['learnRate'])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    print('Model built.')
    
    outputFileDir = 'Outputs/Output%d.txt' % testNum
    outputFile = open(outputFileDir, 'w+')
    outputFile.write('Output' + str(testNum) + '\n' )

    # train the model, output generated text after each iteration
    for iteration in range(1, 3):
        print()
        print('-' * 50)
        print('Iteration', iteration)
        outputFile.write('\n\nIteration' + str(iteration) + '\n')

        model.fit(X, y,
                  batch_size=test['batchSize'],
                  epochs=test['epochs'])

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print('----- diversity:', diversity)
            outputFile.write('\n')
            outputFile.write('----- diversity: ' + str(diversity) + '\n')

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            outputFile.write('----- Generating with seed: "' + sentence + '"' + '\n')
            sys.stdout.write(generated)

            for i in range(400):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                outputFile.write(next_char)
                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
            outputFile.write('\n')
    outputFile.close()
# Out:
# Test Number 0
# nb sequences: 474436
# Vectorization...
# Vectorized.
# Build model...
# Model built.
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 474436/474436 [==============================] - 136s - loss: 1.8603
#
# ----- diversity: 0.2
# ----- Generating with seed: "out robbin armoured trucks,
# if i had one"
# out robbin armoured trucks,
# if i had one the stream that shit it a song it an a song to the street
# shots in the stream the same of the same
# i was shots a bitch you to the stream the street to the streamin' to the same to the to the streamin' to the streetin' to the streamin' to the streamin' to the same to the streamin' to the chorus of the same to the same
# i see it a shots to the streat that i all the stream the stream the streamin' to
#
# ----- diversity: 0.5
# ----- Generating with seed: "out robbin armoured trucks,
# if i had one"
# out robbin armoured trucks,
# if i had one me
# i don't get the street of all the waitin' to the mollion some morned and make the slut shady stand of this how the stream the mome on the fuck a song, it come on the stream on this tell it out to heard to the way or sucked to see me
# i don't want the sameling an a body somet's be to starting the stray i all real 'cause pleat to the sing to be sick to say it's the millin it
# this shit, i ain't in
#
# ----- diversity: 1.0
# ----- Generating with seed: "out robbin armoured trucks,
# if i had one"
# out robbin armoured trucks,
# if i had one shots hunner to back
# want gus to a seat you see that i lope, the clorual
# people like a craim was thatsy ass it mine if
# (a sonul.
# you fall when you fucky a drewn
# need off his some it was is
# sooct and jumply on the mathers it to got of buln to hemped other natch and massy fuck you
# i just still shoteled for you
# should just cla, i like, trumple it godpuls steeton dann smackin op like with a movio ya
#
# ----- diversity: 1.2
# ----- Generating with seed: "out robbin armoured trucks,
# if i had one"
# out robbin armoured trucks,
# if i had one pal dad eilingchrum
# you are o! tlinn custais
# i'mon' to dequine
# i can let us all lade you ies hit oy
# pizcol's me werelly bugged
# look rilors i'm up domor palshouse,
# i kahenegger. titflse if what the ssingwooda gate mirumoof
# ( dadgun?
# pleasess
# untet witch! heereann that to set us
# madged plugs
# so, we gotting, he's it'o. like as stcenaffi'ming shala
# tante some him to same killed a plaw atcr.ƒ-contude
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 474436/474436 [==============================] - 139s - loss: 1.6367
#
# ----- diversity: 0.2
# ----- Generating with seed: "i'm short
# yeah  we gonna have enough ti"
# i'm short
# yeah  we gonna have enough time to this believe a probably through the face and start to start that i don't start the close that i can't shot the motherfuckers to start that i don't see it all the fuck the street
# it's s
