# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Default settings
#     Sequence length = 40
#     Step = 3
#     Units = 128
#     LSTM, DENSE, ACTIVATION
#     Learn Rate = 0.01
#     Batch size = 128
#     Epochs = 1

# %%
defaults = {'maxlen': 40, 'step': 3, 'units': 128, 'learnRate':0.01, 'batchSize':128, 'epochs':1}

#Units
test1 = defaults.copy()
test1['units'] = 256

#2nd LSTM Layer
test2 = defaults.copy()

#Step Size
test3 = defaults.copy()
test3['step'] = 2

#Learn rate
test4 = defaults.copy()
test4['learnRate'] = 0.001

#Batch size
test5 = defaults.copy()
test5['batchSize'] = 64

#Epochs
test6 = defaults.copy()
test6['epochs'] = 3

#Sequence length
test7 = defaults.copy()
test7['maxlen'] = 70

testBank =[defaults, test1, test2, test3, test4, test5, test6, test7]
for test in testBank:
    print(test)
# Out:
# {'epochs': 1, 'step': 3, 'maxlen': 40, 'units': 128, 'batchSize': 128, 'learnRate': 0.01}
# {'epochs': 1, 'step': 3, 'maxlen': 40, 'units': 256, 'batchSize': 128, 'learnRate': 0.01}
# {'epochs': 1, 'step': 3, 'maxlen': 40, 'units': 128, 'batchSize': 128, 'learnRate': 0.01}
# {'epochs': 1, 'step': 2, 'maxlen': 40, 'units': 128, 'batchSize': 128, 'learnRate': 0.01}
# {'epochs': 1, 'step': 3, 'maxlen': 40, 'units': 128, 'batchSize': 128, 'learnRate': 0.001}
# {'epochs': 1, 'step': 3, 'maxlen': 40, 'units': 128, 'batchSize': 64, 'learnRate': 0.01}
# {'epochs': 3, 'step': 3, 'maxlen': 40, 'units': 128, 'batchSize': 128, 'learnRate': 0.01}
# {'epochs': 1, 'step': 3, 'maxlen': 70, 'units': 128, 'batchSize': 128, 'learnRate': 0.01}

# %% [markdown]
# ## Get Eminem Lyrics

# %%
filename = "Eminem/eminem-lyrics.txt"
text = open(filename, "r", encoding="utf8").read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 1423348
# total chars: 90

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Build Model, Train, Test, Repeat

# %%
for testNum, test in enumerate(testBank):
    print("Test Number", testNum)
    # cut the text in semi-redundant sequences of maxlen characters
    maxlen = test['maxlen']
    step = test['step']
    sentences = []
    next_chars = []
    for i in range(0, len(text) - maxlen, step):
        sentences.append(text[i: i + maxlen])
        next_chars.append(text[i + maxlen])
    print('nb sequences:', len(sentences))

    print('Vectorization...')
    X = None
    y = None
    X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            X[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1

    print('Vectorized.')

    # build the model: a single LSTM
    print('Build model...')
    model = Sequential()
    
    if testNum != 2:
        model.add(LSTM(test['units'], input_shape=(maxlen, len(chars))))
    else :
        print('Adding second LSTM layer with units : ' + str(test['units']))
        model.add(LSTM(test['units'], input_shape=(maxlen, len(chars)),return_sequences=True))
        model.add(LSTM(test['units']))
        
    model.add(Dense(len(chars)))
    model.add(Activation('softmax'))

    optimizer = RMSprop(lr=test['learnRate'])
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    print('Model built.')
    
    outputFileDir = 'Outputs/Output%d.txt' % testNum
    outputFile = open(outputFileDir, 'w+')
    outputFile.write('Output' + str(testNum) + '\n' )

    # train the model, output generated text after each iteration
    for iteration in range(1, 15):
        print()
        print('-' * 50)
        print('Iteration', iteration)
        outputFile.write('\n\nIteration' + str(iteration) + '\n')

        model.fit(X, y,
                  batch_size=test['batchSize'],
                  epochs=test['epochs'])

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print('----- diversity:', diversity)
            outputFile.write('\n')
            outputFile.write('----- diversity: ' + str(diversity) + '\n')

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            outputFile.write('----- Generating with seed: "' + sentence + '"' + '\n')
            sys.stdout.write(generated)

            for i in range(400):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                outputFile.write(next_char)
                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()
            outputFile.write('\n')
    outputFile.close()
# Out:
# Test Number 0
# nb sequences: 474436
# Vectorization...
# Vectorized.
# Build model...
# Model built.
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 474436/474436 [==============================] - 141s - loss: 1.8594
#
# ----- diversity: 0.2
# ----- Generating with seed: "me contact buzz
# get me on track, they l"
# me contact buzz
# get me on track, they let me stand the street
# i don't stand the streath the shit to say the street
# i don't want the stress to shit the shit
# it's a say the stre to say it got a say
# i'm a fuckin' to the stret to shot
# i was the same to the fuck the fuck the street
# i don't be the motherfuckin' it and it's a sain the street
# i don't don't like the friend the stream
# i was the fuck the friend and i don't start the street
# when i
#
# ----- diversity: 0.5
# ----- Generating with seed: "me contact buzz
# get me on track, they l"
# me contact buzz
# get me on track, they like a shit suck you some and fart
# they sing the head out startin' to a same
# they man back and say scream to ine well
# meant this on the kidna mean think me to the forg
# they see to this is they walk a larm the start
# fuck it was every dis and it got she to hear the from ame
# i'm a talk to be grate a see you a fuckal
# don't let a sain and all the stecon every day
# i see on the pictul shit motherfucker b
#
# ----- diversity: 1.0
# ----- Generating with seed: "me contact buzz
# get me on track, they l"
# me contact buzz
# get me on track, they leal sents wees you
# uh while susiptidevimiolws wots with me she kneated don't can [cars
# toura little - on a slug
# when i got is one wants this sprestunch and burmver you alf
# uokin' for me like, get up tolve it and flonin' that watcher
# yeah
# wanno then way
# outing fuck life chirss, kab-nest (i would best you um'st something) way sfortwup
# but i don't nevery didn't me this, pleasics and mean me to do it
#
# ----- diversity: 1.2
# ----- Generating with seed: "me contact buzz
# get me on track, they l"
# me contact buzz
# get me on track, they like n, gotta scopze and they blu ratches lost ptare goin' tway
# man, i life me ah on mp
# i'd beeve at a doof  ? degrool take his et take
# i'he is quitar, it'll
# said tonight anyway shiteminokever deed un youlm like shady
# meance, the hry mopeach try mak ! oodzoancide, ahiah 'plai
# rove to try here asksshings on you
# vic,in da dre:, what keors omartxack an aboneceiorsn eadiwin'
# he never try aonly ofbie
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 474436/474436 [==============================] - 143s - loss: 1.6355
#
# ----- diversity: 0.2
# ----- Generating with seed: "h and watch your gut split
# gut you wit "
# h and watch your gut split
# gut you wit the close the cause i don't wanna get the straight and the street to be the straight and it ain't got the close the same to see you the way you ain't start the cramper
# i said i got the close and the more the straight to show the close the crack of me
# i can be a shit and the street in the same shit the straight to the still shots
# i'm a some the come in the body to the way you ain't got the straight
#
# ----- diversity: 0.5
# ----- Generating with seed: "h and watch your gut split
# gut you wit "
# h and watch your gut split
# gut you wit the crimina my shit and maybe that you flow shot down
# when i feel the down, momma same when i don't got the way i can be a bump
# i'm a shoulder strack of us to see you up me out to feel this like the life for been to the rap the way
# you wanna like some straight to the same this bottle in the clitch
# if you got the cause i start in the deadin'
# the child me who don't great me
# and you can class it with
#
# ----- diversity: 1.0
# ----- Generating with seed: "h and watch your gut split
# gut you wit "
# h and watch your gut split
# gut you wit my's crapes than as the was whouch
# you hear no use steal no haigi
# the paced to punted, 'e?
# (my fefty and veriaspin' off, the gure buttiwidpms d, you ame mrice loggay in the wher that's you to shit, yo all eldon
# i get freecter pit your light grave, shake me
# namajs homoooaas they fuck it and loin me
# plun that even brain' of back, again off in a little
# a new from this shit, just ever tourd you i'm o
#
# ----- diversity: 1.2
# ----- Generating with seed: "h and watch your gut split
# gut you wit "
# h and watch your gut split
# gut you wit nohs.. y from without this kill and pac, when i'm songted of !
# i'm is ansach of the somethin' is free!
# yous buyin
# allonly fifter oo eity blow grade
# shadys get leak ndow's line
# im ong up to -?gg rebace of the owd
# you lall here get drunameaci's backbrinkc' miouh turn yo
# wi'en like this in bulline me?
# if then in the new this life for music
# on light to leave me layter i same r offnger
# why to move has
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 474436/474436 [==============================] - 143s - loss: 1.5595
#
# ----- diversity: 0.2
# ----- Generating with seed: " as i'll as can be
# my appeal is to seria"
#  as i'll as can be
# my appeal is to serial i got a little bitch
# i don't got a couple of the back of the street and show the same to see the carse the start
# i don't got the started of the back of the started
# i don't got the startin' the thing in the floor of my see the little bitch
# i got a bad to be the sound and so i don't want to say
# i don't got the same in the started in the start
# and i don't got the same to say i see the too of the s
#
# ----- diversity: 0.5
# ----- Generating with seed: " as i'll as can be
# my appeal is to seria"
#  as i'll as can be
# my appeal is to serial on the christ
# the one one of a store and and
# i been to do it's muh that stard, you feel the world
# and i was the lee on the eat when you have it a little beat show the world
# but it's like this shit gon' please like you might better been to see your little jeaks to my little see the drugs
# can you ain't got the bash stard of some shit in the snoof and tryin' to use a proceed
# so we got barky of a
#
# ----- diversity: 1.0
# ----- Generating with seed: " as i'll as can be
# my appeal is to seria"
#  as i'll as can be
# my appeal is to seriag, workin' back to snoe
# try to actin' irment and bugg rick a loeduckes
# and to reardaw theme, you can be differ
# slammine hold the reap for your mutherfucker
# (petter, try to damn)
# i'll think you beat 'courcolm the trunk
# we'll undermt one of you double apped around
# you alone then the fucking me you got nothere
# you snick with loodi evil clibes
# (no probl]
# i neggot
# of you startie at a feet
# get nuts to
#
# ----- diversity: 1.2
# ----- Generating with seed: " as i'll as can be
# my appeal is to seria"
#  as i'll as can be
# my appeal is to serial, mirsger
# and ewight the lites misticomy, my shake this
# i love the -usa, of my megetcech
# ic's drezela liotin' toy, deg, light mrieterote
# so bud people up, afuck
# unless beat
# i brain it in cabom frolitapor
# droddyana chan)se
# get burning aleaging now, and fivin'
#  same ty if you the neggotoning my canfo live, ninverama, seemerdors neck and, do the pussididr. roming with che and stupid a taatol she t
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
#  - ETA: 61s - loss: 1.5377
#
# ----- diversity: 0.2
# ----- Generating with seed: "out your seat motherfucker, i'm a reach "
# out your seat motherfucker, i'm a reach of the street of the streets
# i don't stand to the street of the floor
# i got a barter and say that i see it and comin'
# i was a bad and the straight out of the streets to stand something
# you take it a damn been in the streets of the streets of the same shood
# i was fuck a million to start the street of the fuck i can't stand the fuck is the beat is stand the streets of the back
# i ain't a back in th
#
# ----- diversity: 0.5
# ----- Generating with seed: "out your seat motherfucker, i'm a reach "
# out your seat motherfucker, i'm a reach is to fact
# when my calla black the face or shoot that while i love you a bitch
# i should get that blood and spitt in the morn of harder to get a fuck and the way to streak you
# when i'm like a fuck your face and dre?
# they ain't a cinderella precter
# i need to be be the dumb in the face
# don't know i was gone, i got a true shots like it's contro
# my back for me to can sure the beat and point a dick in t
#
# ----- diversity: 1.0
# ----- Generating with seed: "out your seat motherfucker, i'm a reach "
# out your seat motherfucker, i'm a reach and cinderella jaky
# when i believe you balights of lowing secsions snorlom ride
# and where's been med, in tubbievul of just comin you for nrig like "g-jna full three fliplin' graby
# he's never gots is toa waes to throers
# alcons and run mama
# cause i short they was doerstany you show about old plages
# i shouldnk murda know you marsled into my name
# take hell
# is eminemin wick my music
# and the ifk where a
#
# ----- diversity: 1.2
# ----- Generating with seed: "out your seat motherfucker, i'm a reach "
# out your seat motherfucker, i'm a reach fakes to twink
# shover like honnibebs klumuar od
# wenct i arelt beem got comar bohhim?
# los (coke m. darky, i'm right my gottedunass)
# i feel three xy
# iesta chronts denesteon up,   fuck fickt ho's eitherwee
# won't a sajused ou conezya fear ptoppant jesaple dustote
# you close your buybshong, mitatyor's now chirrespers
# like our crieme and vick hands creemin', clock,
# yeah?)
# let you sa girl
# so it's
# use do
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
#  - ETA: 117s - loss: 1.5213
#
# ----- diversity: 0.2
# ----- Generating with seed: "s too late to stop it
# there's a certain "
# s too late to stop it
# there's a certain some to the fuckin' bad to can a back to the shit i was a prece
# i was a fuckin' same on me to see me to start to see
# that i said you don't get the same on the mother fuckin' her song
# i don't get the way i was for me to see
# and i got a million in the come and some with me
# when i got a same on the way i was a soldier
# i got a song so dick i said you wanna stand to street to streat the same at the sa
#
# ----- diversity: 0.5
# ----- Generating with seed: "s too late to stop it
# there's a certain "
# s too late to stop it
# there's a certain girl to of the same out here didn't meant to be a mine and i say that my world
# i can't get your shit than a melt
# i ain't got the proba.......
# my name is shit where the world so you say you wanna be a mine of the shot and to see with the way i got the dick in a game
# i was a girl i can a ready and want the fire
# i got gonna probably don't get the shit i don't get like the day
# fuck your shit i don't b
#
# ----- diversity: 1.0
# ----- Generating with seed: "s too late to stop it
# there's a certain "
# s too late to stop it
# there's a certain things bo-off a mather
# fuckin dice liver outside some a
# funver i hurt spent, you're dizaad
# now you feels bitch en, know it i'll fill the gay to end thangin addict for they time
# sell me
# smack that liet's detroit, nase me some here to know
# in the nigha bitch, check your wais is hands
# oging's all so much 'cause you respectly niggas when , but i rady behind it some
# you ye forget me on
# but i can't's
#
# ----- diversity: 1.2
# ----- Generating with seed: "s too late to stop it
# there's a certain "
# s too late to stop it
# there's a certain
# washing, , ne"w  collcwe, that yo, bully kin, misoddays, that if he was ubbacs
# econgual
# let it a bluck wellics
# and my muan and goet o-pmongs
# than not like a fuckin' walkin bone, you can't givin' sucked once. don't lrost
# best , funnius conver nopkin penper and in tha e cowxengiwss
# now slim shady binn kinys, yow i got on
# so theis no, think i got himmats's suh "buiam addroodbm you gen cry countamon
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 474436/474436 [==============================] - 142s - loss: 1.5126    7
#
# ----- diversity: 0.2
# ----- Generating with seed: " eddie, twenty-three years old
# fed up wi"
#  eddie, twenty-three years old
# fed up with a standing to the way i was for the fuckin stand of the streets
# i don't get the beat to me to change some start
# i don't get the street and the back and so be the streets
# i don't know it's all the streets and the course and don't don't know what i don't know what i don't get the streets
# i'm the shit i was for the streets
# i don't stand in the same life i don't see the fuckin beat in the streets
# t
#
# ----- diversity: 0.5
# ----- Generating with seed: " eddie, twenty-three years old
# fed up wi"
#  eddie, twenty-three years old
# fed up with me, i'm fortone to the chance
# i don't let a fuck i can be here so like
# i ain't got the call me on the same chance some sorry each off
# older could you don't got a real of a soldier
# the fuck i got a too the part of the shots back and never been to the dawg
# cause i say that i can't see the street with the mother out of my shots
# but i don't see the mic on the front and the fuck
# you guess is the fuc
#
# ----- diversity: 1.0
# ----- Generating with seed: " eddie, twenty-three years old
# fed up wi"
#  eddie, twenty-three years old
# fed up without
# full it raised my high me
# we're shit i ain't shoke
# some bloodall
# and uphand so time in they shot, i've don't placen
# i ever stand
# time and you fo thus-unney brother
# at hold the record
# oe ih thath you curse you right i don't don't get shoo his scash
# you hizqaa:, 'till you nuterie i mean task, i'm same
# i'm dissieavan, spill me and there?
# oh
# awnma when you don't get od seeirs, ho's cripped bre
#
# ----- diversity: 1.2
# ----- Generating with seed: " eddie, twenty-three years old
# fed up wi"
#  eddie, twenty-three years old
# fed up without to niggas you eminem.
# what's bill so full i keep hate upth it's beav for joke
# oh, ail potronic, coulder's frotin's fortotha rab- girgs a rhy?
# do i feel it up the room
# less time
# my ly! that's jlase you ill that i die, junten
# you suctby all the mo, trees like
# i never feems you end it go snip's that's so rayiouses boting the beat
# fuck your gaf, cause you's meanem, mat, yeah, i'm snicker
# he's t
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
#  38272/474436 [=>............................] - ETA: 132s - loss: 1.4941
