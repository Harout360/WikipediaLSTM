# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
# Out:
# Using TensorFlow backend.

# %%
filename = "eminem-lyrics.txt"
text = open(filename, "r", encoding="utf8").read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# corpus length: 1423348
# total chars: 90
# nb sequences: 474436

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
    
print('Vectorized.')
# Out:
# Vectorization...
# Vectorized.

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Model built.')
# Out:
# Build model...
# Model built.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 474436/474436 [==============================] - 138s - loss: 1.8781
#
# ----- diversity: 0.2
# ----- Generating with seed: " said you was beautiful
# diabolical, till"
#  said you was beautiful
# diabolical, till the bord in the back and it's the way the strut the cound the same it
# i don't be a startin the some to startin' the strut and shit with a penchin' and some think it wanna see it and start and something it of a sent to be a strut and should so man i was so man i a sold me and start and the that it and some with a sick and shit and shit
# and it's a sick the real a fuckin' and shit and startin' the b
#
# ----- diversity: 0.5
# ----- Generating with seed: " said you was beautiful
# diabolical, till"
#  said you was beautiful
# diabolical, till, i'm so it with doused to do back i'm at what i know i'm with the one and some with suppack to the touch and
# it's crush that grabbed and when i stoppin marth, so beat and some with a second and so a lands
# i can do them back with a rider
# i'll feekin' the chicker sold and but the picks bitch in a dong with the might that this in white in the coure
# when i side it the shit we the probled more think
#
# ----- diversity: 1.0
# ----- Generating with seed: " said you was beautiful
# diabolical, till"
#  said you was beautiful
# diabolical, tills druak
# i like off aps to this singli to through be go
# it's pusseact of the for new a car strulas get rongs but or behas wanna can ghinta
# wrugh
# ustenf?s when ack abbit a mn caman' aftoor thought me
# i think a back, of the einto wouldn't go, sfunin just saught for a ridle
# your hearside
# if could thest floullle a , if yeah, i'm that a fack of bethoushin' wastil like you couthm bitches what my lack whe
#
# ----- diversity: 1.2
# ----- Generating with seed: " said you was beautiful
# diabolical, till"
#  said you was beautiful
# diabolical, till hater allie this carsies agaate
# we gome
# we areard the fcond, i elpre ann, nieters, is ruminh that what at a, your song
# fage that'll right jumie funnit, eally, is just ãjust finy a stual co]
# who's becalioh tides that and thrott)
# on
# turn me no ity, so h here's alrowdidiymmant go, 3luse it! 'cyoof of anyselash op
# thouck if it singrealy nic la 'sh of namel,
# they just liqhose i'm ass sing
# i'le give wi
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
#  - ETA: 48s - loss: 1.6514
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# yo left, yo left, yo left, right, left
# "
#
# yo left, yo left, yo left, right, left
# where the way i don't still i want the streets
# the shit it are a stop in the shot
# i got a strut the explease in the shot to start the way
# the way i want the way i don't got a tate in the shit
# i don't want it and still the dick to stand the way
# i don't got a strut the way
# i ain't got it back to the shit
# so where the shit the way i don't got a million to street
# i was a strap to the shot to start the
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# yo left, yo left, yo left, right, left
# "
#
# yo left, yo left, yo left, right, left
# i don't got a street in the crands of to life
# i had a sauce to start a fuck your fucka
# it's a dear what startin' a scream me
# i ain't goin' on the own shady
# i want the dish like a shoulda still shit
# i don't been back to be a way
# you say the shot the shot to party strong where you
# and stard the porty grund 'cause i'm enough the eose come at your lats to shady
# we don't want the shit it to do how the
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# yo left, yo left, yo left, right, left
# "
#
# yo left, yo left, yo left, right, left
# and i
# or hit the penie away!
# 't on toard in her move doca too face
# and slump runving alain and go, nagge
# hertneas, all -ons
# so heing
# i just aem feet my clothe
# make it aille rapgate take juse i'm goin', eee!
# he even just in macinmeny caped, finish hits
# if i wantpiner, and laked up bivin at the ceening
# but we ain't smilly women gayme
# so the way and lakin' to get comman howing
# ugah ain't been tate, h
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# yo left, yo left, yo left, right, left
# "
#
# yo left, yo left, yo left, right, left
# juse in thas, go, gut back-fuck, or u, abod withare ir a gluggs it
# drame conly passty"
# if it's it askiirling bubfemkit
# cubambup put back but is white
# hard, - canil his fussid
# goin' had blase the shickeray!
# whateh
# kide
# sank, no off or lef
# yaw can hurtiopfitizeton
# and !glnunp a-maps, espudgege up
# you're about a leave fore it, time
# murderuitly, diwe
# undip, down we'enn icker flick : zel
# y
# how hot it (
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 474436/474436 [==============================] - 140s - loss: 1.5792
#
# ----- diversity: 0.2
# ----- Generating with seed: "uckas
# [chorus]
# [eminem]
# do-ra-me, fa-s"
# uckas
# [chorus]
# [eminem]
# do-ra-me, fa-should a straight the fuck it and i got a streched in my spin the streneme in the streneas
# i don't wanna be a streney as the way i don't want you the street and i don't wanna be a strengs in my spin i just see me to me
# i don't wanna be a strecit and swing me the streneas off the fuck it and i don't want the streneme to me
# i don't wanna be a street and shit in my people to be the tasters and swing a
#
# ----- diversity: 0.5
# ----- Generating with seed: "uckas
# [chorus]
# [eminem]
# do-ra-me, fa-s"
# uckas
# [chorus]
# [eminem]
# do-ra-me, fa-sot
# i don't know i been shit and they styped they know you start your on a mind as a seming of first of a real, i don't want me head
# they see me and you say you say i pack off the walk out and you don't wanna be blig back and even his was the driggers
# and i can i what i have you never slim in a block the way you got some mentite in a shit shit in the wron'
# i was a your a duck 'fuckin' the words wal
#
# ----- diversity: 1.0
# ----- Generating with seed: "uckas
# [chorus]
# [eminem]
# do-ra-me, fa-s"
# uckas
# [chorus]
# [eminem]
# do-ra-me, fa-sars. wet from who they aire ubd up, madbe
# while but ohe?
# under sorecled in real
# just it try to get're comin'
# now, what unther, tonight but they're livin'
# i ill can i smack you make my wame
# that's had rappere's ar makies with it and and factin' arti
# hard folled when you're nob the off getrito another they ridof when panted
# feelin' me satting about to the fhind out
# so if you talk, don't would song
#
# ----- diversity: 1.2
# ----- Generating with seed: "uckas
# [chorus]
# [eminem]
# do-ra-me, fa-s"
# uckas
# [chorus]
# [eminem]
# do-ra-me, fa-shan men, my folled nut loors
# with me, capting it if y'mel
# my goliata and ob, dont go onponientuc damus
# yoq wor't somethin' resius a bext
# until no on, not sotin' bombed they fuckin'
# just dedisted them let you thgerd, i it scrizencic
# shit up a if shegs wilt gaege, colbisange let i still do that punk
# i'll the edn
# durt atreguid
# i im blifd who and all asue i trissoy it
# it's dables cim
# i guess whentio
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 474436/474436 [==============================] - 140s - loss: 1.5684
#
# ----- diversity: 0.2
# ----- Generating with seed: "r we see
# change my name in n-y they don'"
# r we see
# change my name in n-y they don't got a push me
# i was the true of the same of the shit
# i wanna fuck it and the same to me
# i say i can see i can see i don't get it with the courted out the same to me
# i said i can get so what i was what i don't know you ask a care the same to me
# i don't know it out the ball and the same to me
# i wanna say that i don't got a care the same to me
# i say i say i talk a care to the shook and stand to get
#
# ----- diversity: 0.5
# ----- Generating with seed: "r we see
# change my name in n-y they don'"
# r we see
# change my name in n-y they don't know the protion
# the momene shit and as my face is
# call me, so believe the back, i say i love me was the home,
# and i don't say that i got you to startin'
# and i don't give a fuck and the world i said and be, dre
# you gotta think i don't talk a dick in my name of him with the more,
# and they scream and for me
# i hold it here and the woolin' day in the feethem
# i been alroof i would let me see the whol
#
# ----- diversity: 1.0
# ----- Generating with seed: "r we see
# change my name in n-y they don'"
# r we see
# change my name in n-y they don't give a bettin'
# rappin' a fuck profla motherfuckers got to proof watt in the g@jss, enter
# last put u
# C:\Users\Harout\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: divide by zero encountered in log
# p ladie or crazy mastah girl
# (our mared as this no phot's alsays, yeah, i guess i'm out with a light
# [if it can't be the hand when you shit engive??
# leave us like the is than charge to fight
# dally cromplin dee
# dishole-plus all man  fly the first
# pleaser huck off and wantedy if i said
# wars out in th
#
# ----- diversity: 1.2
# ----- Generating with seed: "r we see
# change my name in n-y they don'"
# r we see
# change my name in n-y they don't let lings
# alsow i knose, juhnys, with daum
# hawkite by my buffete that, wall
# nowhere crushes is souder, that's what would be untilol, but to my ha arrou muce shit
# so cildch, and yearnivesdal morning
# shro-the, of manseffih your meth¼jfas toran
# i never let a better like doing
# a life the soupter, you knot this wrong rocks, duutched to stuck with a chaseds
# [iiousbells up)
# letter again
# now
# i walk a l
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 474436/474436 [==============================] - 138s - loss: 1.5954
#
# ----- diversity: 0.2
# ----- Generating with seed: "my couch, bitch", pull a nine out during"
# my couch, bitch", pull a nine out during to the place with the back and start the street
# i don't know what i wanna get a starts to change to the shit
# the fucking thing is the fucking shit is the world
# i can see it all the fucking the shit is a back
# you can start the starts and like a little bitch
# the fuck i'm the strung like the starts and a sets in the struin
# i got the black to the fucking to the back
# i can be the way i can see it ou
#
# ----- diversity: 0.5
# ----- Generating with seed: "my couch, bitch", pull a nine out during"
# my couch, bitch", pull a nine out during to the trine
# i can see the tell the day the back
# from the chairs to stand me to fight for the little
# but you said it from the fuck it and bitch, get you for the mother and when i ask the shit
# the s'em #sangely and back, i'm sure me
# i can help in the back to me the street for the time to the floor
# i never keep to be me, what the fuck off you problem
# cause i remember in the rest back to on be a res
#
# ----- diversity: 1.0
# ----- Generating with seed: "my couch, bitch", pull a nine out during"
# my couch, bitch", pull a nine out during back in the show to feet pussy
# and you list killed
# i'l wrack upin me run in the world
# shit's a and be stops suin with
# you're fact-unton realous we fuckin 'cuz
# if dont rays to chriside touch
# happin' the fiersz deper, tricked, muffing felsite that fhourderboy sate la o- right get a heave get me a unter the voite
# you bound getting 'in
# and i hope my smokatllas an drases up brain
# my kurijamstett up b
#
# ----- diversity: 1.2
# ----- Generating with seed: "my couch, bitch", pull a nine out during"
# my couch, bitch", pull a nine out during in cygaculor
# do this times's a bate daid you and goddentrofuzza down and inbuosed this shirl
# flee amiunt man who keds come eaping it senntin it
# if i can be leed mplab loco, releast,
# till can this ispet, i'm liy it, new
# alsope, on defornted bufty
# ertef like from my shitrybod atty shit, i mofuching,
# aristen swifd, shinatea oflic- "i were what, white uppartrytos ?
# lich
# haw 'em ust gatald her, goun
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
